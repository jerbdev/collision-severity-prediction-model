# %% [markdown]
# # IBM Data Science: Applied Data Science Capstone

# %% [markdown]
# This notebook will mainly be used for the capstone project of the IBM Professional Data Science certificate.

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
